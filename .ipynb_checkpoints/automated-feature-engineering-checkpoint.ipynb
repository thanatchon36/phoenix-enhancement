# %%
import pandas as pd
import time
import datetime
pd.options.display.float_format = '{:,}'.format
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.options.display.float_format = '{:,}'.format

#https://docs.featuretools.com/en/stable/
import featuretools as ft
print('OK !')
# Out:
# OK !

# %%
df = pd.read_csv('data/Data_Phoenix_Campaign_Enhancement.csv')

len(df)
# Out:
# 152451

# %%
df['actual_offer_percent'] = df['campaign_premium']*100 / df['policy_annual_premium']
df['offer_score'] = df['campaign_offer_percent'] - df['actual_offer_percent']

# %%
def change_dt(num):
    num = str(num)
    year = num[:4]
    mon = num[-2:]
    return datetime.datetime(int(year), int(mon), 1)
df['campaign_offer_date'] = df['campaign_offer_date'].astype(str)
df['campaign_offer_date'] = df['campaign_offer_date'].apply(change_dt)

# %%
df['current_holding'] = df['campaign_offer_product'].map(str) + '_'+\
                    df['cus_ct_A1_product_holding'].map(str) + '_'+\
                    df['cus_ct_A2_product_holding'].map(str) + '_'+\
                    df['cus_ct_C1_product_holding'].map(str) + '_'+\
                    df['cus_ct_E1_product_holding'].map(str) + '_'+\
                    df['cus_ct_H1_product_holding'].map(str) + '_'+\
                    df['cus_ct_H2_product_holding'].map(str) 

prod_dict = {}
prod_dict['A1'] = 1
prod_dict['A2'] = 2
prod_dict['C1'] = 3
prod_dict['E1'] = 4
prod_dict['H1'] = 5
prod_dict['H2'] = 6

prod_dict

def is_existing(prod_text):
    prod_list = prod_text.split('_')
    prod_name = prod_list[0]
    
    cur_num = prod_list[prod_dict[prod_name]]
    
    return int(cur_num) 

df['current_holding'] = df['current_holding'].apply(is_existing)
# Out:
# {'A1': 1, 'A2': 2, 'C1': 3, 'E1': 4, 'H1': 5, 'H2': 6}

# %%
cols = ['policy_id','customer_age','customer_gender','cus_marital_status']
pol_df = df[cols].drop_duplicates()

cols = pol_df.columns
pol_df = pol_df.groupby('policy_id').first().reset_index()[cols]

pol_df.head()
# Out:
#    policy_id  customer_age customer_gender cus_marital_status
# 0  796480931            19               M          01 Single
# 1  796501030             9               F          01 Single
# 2  796501205            17               F          01 Single
# 3  796501276            53               M          02 Maried
# 4  796501289            29               M          01 Single

# %%
cols = ['policy_id','campaign_offer_date','policy_annual_premium','campaign_premium',
        'campaign_offer_percent','campaign_offer_product','actual_offer_percent','offer_score',
        'campaign_take_up',
        'current_holding'
        ]
offer_df = df[cols].drop_duplicates().reset_index()
offer_df=offer_df.rename(columns = {'index':'offer_id'})
offer_df.head()
# Out:
#    offer_id  policy_id campaign_offer_date  policy_annual_premium  \
# 0         0  997625582          2017-01-01                  60345
# 1         1  997625582          2018-01-01                  60345
# 2         2  997585949          2017-02-01                  88095
# 3         3  997585949          2018-02-01                  88095
# 4         4  997578875          2017-02-01                  75510
#
#    campaign_premium  campaign_offer_percent campaign_offer_product  \
# 0              4881                      10                     C1
# 1              8145                      15                     E1
# 2              4500                      10                     A1
# 3              9375                      15                     A2
# 4              4500                      10                     A1
#
#    actual_offer_percent        offer_score campaign_take_up  current_holding
# 0     8.088491175739497  1.911508824260503                N                1
# 1    13.497390007457122 1.5026099925428777                N                0
# 2     5.108121913843011  4.891878086156989                N                1
# 3    10.641920653839605  4.358079346160395                N                2
# 4     5.959475566150179  4.040524433849821                N                0

# %%
entities = {
       "policies" : (pol_df, "policy_id"),
       "offers" : (offer_df, "offer_id", "campaign_offer_date"),
    }

relationships = [("policies", "policy_id", "offers", "policy_id")]

ft.EntitySet("my-entity-set", entities, relationships).plot()

# %%
es = ft.EntitySet("my-entity-set", entities, relationships)
es["offers"]["campaign_take_up"].interesting_values = ["Y", "N"]
es["offers"]["campaign_offer_product"].interesting_values = ["E1", "A1", "A2", "C1","H1","H2"]

# %%
start_time = time.time()

feature_matrix_policy, features_defs = ft.dfs(entities=es,  entityset=es,
                         agg_primitives=['max','median','trend','avg_time_between',\
                                         'min','std','mean','sum','skew',\
                                         'count','mode','last','time_since_first'
                                                                    ],
                        where_primitives=['max','median','trend','avg_time_between',\
                                         'min','std','mean','sum','skew',\
                                         'count','mode','last','time_since_first'
                                                                    ],
                                                 
                                         ignore_variables={'offers': ["offer_id"]},
                                                     target_entity="policies"
                                        )
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-69c9bed34dba> in <module>
#      12
#      13                                          ignore_variables={'offers': ["offer_id"]},
# ---> 14                                                      target_entity="policies"
#      15                                         )
#      16 print("--- %s seconds ---" % (time.time() - start_time))
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/utils/entry_point.py in function_wrapper(*args, **kwargs)
#      36                 # call function
#      37                 start = time.time()
# ---> 38                 return_value = func(*args, **kwargs)
#      39                 runtime = time.time() - start
#      40             except Exception as e:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/synthesis/dfs.py in dfs(entities, relationships, entityset, target_entity, cutoff_time, instance_ids, agg_primitives, trans_primitives, groupby_trans_primitives, allowed_paths, max_depth, ignore_entities, ignore_variables, seed_features, drop_contains, drop_exact, where_primitives, max_features, cutoff_time_in_index, save_progress, features_only, training_window, approximate, chunk_size, n_jobs, dask_kwargs, verbose, return_variable_types)
#     226                                                   n_jobs=n_jobs,
#     227                                                   dask_kwargs=dask_kwargs,
# --> 228                                                   verbose=verbose)
#     229     return feature_matrix, features
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/computational_backends/calculate_feature_matrix.py in calculate_feature_matrix(features, entityset, cutoff_time, instance_ids, entities, relationships, cutoff_time_in_index, training_window, approximate, save_progress, verbose, chunk_size, n_jobs, dask_kwargs)
#     265                                                  cutoff_df_time_var=cutoff_df_time_var,
#     266                                                  target_time=target_time,
# --> 267                                                  pass_columns=pass_columns)
#     268
#     269     feature_matrix = pd.concat(feature_matrix)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/computational_backends/calculate_feature_matrix.py in linear_calculate_chunks(chunks, feature_set, approximate, training_window, verbose, save_progress, entityset, no_unapproximated_aggs, cutoff_df_time_var, target_time, pass_columns)
#     496                                           no_unapproximated_aggs,
#     497                                           cutoff_df_time_var,
# --> 498                                           target_time, pass_columns)
#     499         feature_matrix.append(_feature_matrix)
#     500         # Do a manual garbage collection in case objects from calculate_chunk
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/computational_backends/calculate_feature_matrix.py in calculate_chunk(chunk, feature_set, entityset, approximate, training_window, verbose, save_progress, no_unapproximated_aggs, cutoff_df_time_var, target_time, pass_columns)
#     341                                            ids,
#     342                                            precalculated_features=precalculated_features_trie,
# --> 343                                            training_window=window)
#     344
#     345             id_name = _feature_matrix.index.name
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/computational_backends/utils.py in wrapped(*args, **kwargs)
#      35         def wrapped(*args, **kwargs):
#      36             if save_progress is None:
# ---> 37                 r = method(*args, **kwargs)
#      38             else:
#      39                 time = args[0].to_pydatetime()
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/computational_backends/calculate_feature_matrix.py in calc_results(time_last, ids, precalculated_features, training_window)
#     316                                               ignored=all_approx_feature_set)
#     317
# --> 318             matrix = calculator.run(ids)
#     319             return matrix
#     320
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/computational_backends/feature_set_calculator.py in run(self, instance_ids)
#     101                                             precalculated_trie=self.precalculated_features,
#     102                                             filter_variable=target_entity.index,
# --> 103                                             filter_values=instance_ids)
#     104
#     105         # The dataframe for the target entity should be stored at the root of
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/computational_backends/feature_set_calculator.py in _calculate_features_for_entity(self, entity_id, feature_trie, df_trie, full_entity_df_trie, precalculated_trie, filter_variable, filter_values, parent_data)
#     278
#     279         # Calculate all features that don't require the full entity.
# --> 280         df = self._calculate_features(df, df_trie, not_full_entity_features)
#     281
#     282         # Step 5: Store the dataframe for this entity at the root of df_trie, so
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/computational_backends/feature_set_calculator.py in _calculate_features(self, df, df_trie, features)
#     293             representative_feature = group[0]
#     294             handler = self._feature_type_handler(representative_feature)
# --> 295             df = handler(group, df, df_trie)
#     296
#     297         return df
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/computational_backends/feature_set_calculator.py in _calculate_agg_features(self, features, frame, df_trie)
#     585                 # the column (in actuality grouping by both index and group would
#     586                 # work)
# --> 587                 to_merge = base_frame.groupby(base_frame[groupby_var], observed=True, sort=False).apply(wrap)
#     588                 frame = pd.merge(left=frame, right=to_merge,
#     589                                  left_index=True,
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     733         with option_context("mode.chained_assignment", None):
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#     737                 # gh-20949
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     749
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#     753         return self._wrap_applied_output(
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     170         ):
#     171             try:
# --> 172                 result_values, mutated = splitter.fast_apply(f, group_keys)
#     173
#     174             except libreduction.InvalidApply as err:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/groupby/ops.py in fast_apply(self, f, names)
#     929
#     930         sdata = self._get_sorted_data()
# --> 931         return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#     932
#     933     def _chop(self, sdata: DataFrame, slice_obj: slice) -> DataFrame:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/computational_backends/feature_set_calculator.py in wrap(df)
#     669                 values = func(*args, time=time_last)
#     670             else:
# --> 671                 values = func(*args)
#     672
#     673             if f.number_output_features == 1:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/featuretools/primitives/standard/aggregation_primitives.py in pd_trend(y, x)
#     579     def get_function(self):
#     580         def pd_trend(y, x):
# --> 581             df = pd.DataFrame({"x": x, "y": y}).dropna()
#     582             if df.shape[0] <= 2:
#     583                 return np.nan
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      72     axes = [ensure_index(columns), index]
#      73
# ---> 74     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      75
#      76
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1669     try:
#    1670         blocks = form_blocks(arrays, names, axes)
# -> 1671         mgr = BlockManager(blocks, axes)
#    1672         mgr._consolidate_inplace()
#    1673         return mgr
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     139             self._verify_integrity()
#     140
# --> 141         self._consolidate_check()
#     142
#     143         self._rebuild_blknos_and_blklocs()
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/managers.py in _consolidate_check(self)
#     654
#     655     def _consolidate_check(self):
# --> 656         ftypes = [blk.ftype for blk in self.blocks]
#     657         self._is_consolidated = len(ftypes) == len(set(ftypes))
#     658         self._known_consolidated = True
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     654
#     655     def _consolidate_check(self):
# --> 656         ftypes = [blk.ftype for blk in self.blocks]
#     657         self._is_consolidated = len(ftypes) == len(set(ftypes))
#     658         self._known_consolidated = True
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in ftype(self)
#     347         else:
#     348             dtype = self.dtype
# --> 349         return f"{dtype}:{self._ftype}"
#     350
#     351     def merge(self, other):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_dtype.py in __str__(dtype)
#      52         return dtype.str
#      53     else:
# ---> 54         return dtype.name
#      55
#      56
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_dtype.py in _name_get(dtype)
#     345
#     346     # append bit counts
# --> 347     if _name_includes_bit_suffix(dtype):
#     348         name += "{}".format(dtype.itemsize * 8)
#     349
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/numpy/core/_dtype.py in _name_includes_bit_suffix(dtype)
#     321         # pointer size varies by system, best to omit it
#     322         return False
# --> 323     elif dtype.type == np.bool_:
#     324         # implied
#     325         return False
#
# KeyboardInterrupt:

# %%
#feature_matrix_policy is compressed as feature_matrix_policy.csv.zip in data directory
feature_matrix_policy.to_csv('data/feature_matrix_policy.csv',index= False)

# %%
feature_matrix_policy = pd.read_csv('data/feature_matrix_policy.csv')
# Out:
# /Users/thanatchonchongmankhong/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (476,568) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(feature_matrix_policy.columns)
for each in feature_matrix_policy.columns:
    print(each)
# Out:
# 604
# policy_id
# customer_age
# customer_gender
# cus_marital_status
# MAX(offers.offer_score)
# MAX(offers.policy_annual_premium)
# MAX(offers.current_holding)
# MAX(offers.campaign_premium)
# MAX(offers.actual_offer_percent)
# MAX(offers.campaign_offer_percent)
# MEDIAN(offers.offer_score)
# MEDIAN(offers.policy_annual_premium)
# MEDIAN(offers.current_holding)
# MEDIAN(offers.campaign_premium)
# MEDIAN(offers.actual_offer_percent)
# MEDIAN(offers.campaign_offer_percent)
# TREND(offers.policy_annual_premium, campaign_offer_date)
# TREND(offers.current_holding, campaign_offer_date)
# TREND(offers.campaign_offer_percent, campaign_offer_date)
# TREND(offers.campaign_premium, campaign_offer_date)
# TREND(offers.actual_offer_percent, campaign_offer_date)
# TREND(offers.offer_score, campaign_offer_date)
# AVG_TIME_BETWEEN(offers.campaign_offer_date)
# MIN(offers.offer_score)
# MIN(offers.policy_annual_premium)
# MIN(offers.current_holding)
# MIN(offers.campaign_premium)
# MIN(offers.actual_offer_percent)
# MIN(offers.campaign_offer_percent)
# STD(offers.offer_score)
# STD(offers.policy_annual_premium)
# STD(offers.current_holding)
# STD(offers.campaign_premium)
# STD(offers.actual_offer_percent)
# STD(offers.campaign_offer_percent)
# MEAN(offers.offer_score)
# MEAN(offers.policy_annual_premium)
# MEAN(offers.current_holding)
# MEAN(offers.campaign_premium)
# MEAN(offers.actual_offer_percent)
# MEAN(offers.campaign_offer_percent)
# SUM(offers.offer_score)
# SUM(offers.policy_annual_premium)
# SUM(offers.current_holding)
# SUM(offers.campaign_premium)
# SUM(offers.actual_offer_percent)
# SUM(offers.campaign_offer_percent)
# SKEW(offers.offer_score)
# SKEW(offers.policy_annual_premium)
# SKEW(offers.current_holding)
# SKEW(offers.campaign_premium)
# SKEW(offers.actual_offer_percent)
# SKEW(offers.campaign_offer_percent)
# MODE(offers.campaign_offer_product)
# MODE(offers.campaign_take_up)
# LAST(offers.offer_score)
# LAST(offers.policy_annual_premium)
# LAST(offers.current_holding)
# LAST(offers.campaign_offer_product)
# LAST(offers.campaign_premium)
# LAST(offers.actual_offer_percent)
# LAST(offers.campaign_offer_percent)
# LAST(offers.campaign_take_up)
# TIME_SINCE_FIRST(offers.campaign_offer_date)
# MAX(offers.offer_score WHERE campaign_take_up = Y)
# MAX(offers.offer_score WHERE campaign_offer_product = H2)
# MAX(offers.offer_score WHERE campaign_offer_product = H1)
# MAX(offers.offer_score WHERE campaign_offer_product = A2)
# MAX(offers.offer_score WHERE campaign_take_up = N)
# MAX(offers.offer_score WHERE campaign_offer_product = E1)
# MAX(offers.offer_score WHERE campaign_offer_product = A1)
# MAX(offers.offer_score WHERE campaign_offer_product = C1)
# MAX(offers.policy_annual_premium WHERE campaign_take_up = Y)
# MAX(offers.policy_annual_premium WHERE campaign_offer_product = H2)
# MAX(offers.policy_annual_premium WHERE campaign_offer_product = H1)
# MAX(offers.policy_annual_premium WHERE campaign_offer_product = A2)
# MAX(offers.policy_annual_premium WHERE campaign_take_up = N)
# MAX(offers.policy_annual_premium WHERE campaign_offer_product = E1)
# MAX(offers.policy_annual_premium WHERE campaign_offer_product = A1)
# MAX(offers.policy_annual_premium WHERE campaign_offer_product = C1)
# MAX(offers.current_holding WHERE campaign_take_up = Y)
# MAX(offers.current_holding WHERE campaign_offer_product = H2)
# MAX(offers.current_holding WHERE campaign_offer_product = H1)
# MAX(offers.current_holding WHERE campaign_offer_product = A2)
# MAX(offers.current_holding WHERE campaign_take_up = N)
# MAX(offers.current_holding WHERE campaign_offer_product = E1)
# MAX(offers.current_holding WHERE campaign_offer_product = A1)
# MAX(offers.current_holding WHERE campaign_offer_product = C1)
# MAX(offers.campaign_premium WHERE campaign_take_up = Y)
# MAX(offers.campaign_premium WHERE campaign_offer_product = H2)
# MAX(offers.campaign_premium WHERE campaign_offer_product = H1)
# MAX(offers.campaign_premium WHERE campaign_offer_product = A2)
# MAX(offers.campaign_premium WHERE campaign_take_up = N)
# MAX(offers.campaign_premium WHERE campaign_offer_product = E1)
# MAX(offers.campaign_premium WHERE campaign_offer_product = A1)
# MAX(offers.campaign_premium WHERE campaign_offer_product = C1)
# MAX(offers.actual_offer_percent WHERE campaign_take_up = Y)
# MAX(offers.actual_offer_percent WHERE campaign_offer_product = H2)
# MAX(offers.actual_offer_percent WHERE campaign_offer_product = H1)
# MAX(offers.actual_offer_percent WHERE campaign_offer_product = A2)
# MAX(offers.actual_offer_percent WHERE campaign_take_up = N)
# MAX(offers.actual_offer_percent WHERE campaign_offer_product = E1)
# MAX(offers.actual_offer_percent WHERE campaign_offer_product = A1)
# MAX(offers.actual_offer_percent WHERE campaign_offer_product = C1)
# MAX(offers.campaign_offer_percent WHERE campaign_take_up = Y)
# MAX(offers.campaign_offer_percent WHERE campaign_offer_product = H2)
# MAX(offers.campaign_offer_percent WHERE campaign_offer_product = H1)
# MAX(offers.campaign_offer_percent WHERE campaign_offer_product = A2)
# MAX(offers.campaign_offer_percent WHERE campaign_take_up = N)
# MAX(offers.campaign_offer_percent WHERE campaign_offer_product = E1)
# MAX(offers.campaign_offer_percent WHERE campaign_offer_product = A1)
# MAX(offers.campaign_offer_percent WHERE campaign_offer_product = C1)
# MEDIAN(offers.offer_score WHERE campaign_take_up = Y)
# MEDIAN(offers.offer_score WHERE campaign_offer_product = H2)
# MEDIAN(offers.offer_score WHERE campaign_offer_product = H1)
# MEDIAN(offers.offer_score WHERE campaign_offer_product = A2)
# MEDIAN(offers.offer_score WHERE campaign_take_up = N)
# MEDIAN(offers.offer_score WHERE campaign_offer_product = E1)
# MEDIAN(offers.offer_score WHERE campaign_offer_product = A1)
# MEDIAN(offers.offer_score WHERE campaign_offer_product = C1)
# MEDIAN(offers.policy_annual_premium WHERE campaign_take_up = Y)
# MEDIAN(offers.policy_annual_premium WHERE campaign_offer_product = H2)
# MEDIAN(offers.policy_annual_premium WHERE campaign_offer_product = H1)
# MEDIAN(offers.policy_annual_premium WHERE campaign_offer_product = A2)
# MEDIAN(offers.policy_annual_premium WHERE campaign_take_up = N)
# MEDIAN(offers.policy_annual_premium WHERE campaign_offer_product = E1)
# MEDIAN(offers.policy_annual_premium WHERE campaign_offer_product = A1)
# MEDIAN(offers.policy_annual_premium WHERE campaign_offer_product = C1)
# MEDIAN(offers.current_holding WHERE campaign_take_up = Y)
# MEDIAN(offers.current_holding WHERE campaign_offer_product = H2)
# MEDIAN(offers.current_holding WHERE campaign_offer_product = H1)
# MEDIAN(offers.current_holding WHERE campaign_offer_product = A2)
# MEDIAN(offers.current_holding WHERE campaign_take_up = N)
# MEDIAN(offers.current_holding WHERE campaign_offer_product = E1)
# MEDIAN(offers.current_holding WHERE campaign_offer_product = A1)
# MEDIAN(offers.current_holding WHERE campaign_offer_product = C1)
# MEDIAN(offers.campaign_premium WHERE campaign_take_up = Y)
# MEDIAN(offers.campaign_premium WHERE campaign_offer_product = H2)
# MEDIAN(offers.campaign_premium WHERE campaign_offer_product = H1)
# MEDIAN(offers.campaign_premium WHERE campaign_offer_product = A2)
# MEDIAN(offers.campaign_premium WHERE campaign_take_up = N)
# MEDIAN(offers.campaign_premium WHERE campaign_offer_product = E1)
# MEDIAN(offers.campaign_premium WHERE campaign_offer_product = A1)
# MEDIAN(offers.campaign_premium WHERE campaign_offer_product = C1)
# MEDIAN(offers.actual_offer_percent WHERE campaign_take_up = Y)
# MEDIAN(offers.actual_offer_percent WHERE campaign_offer_product = H2)
# MEDIAN(offers.actual_offer_percent WHERE campaign_offer_product = H1)
# MEDIAN(offers.actual_offer_percent WHERE campaign_offer_product = A2)
# MEDIAN(offers.actual_offer_percent WHERE campaign_take_up = N)
# MEDIAN(offers.actual_offer_percent WHERE campaign_offer_product = E1)
# MEDIAN(offers.actual_offer_percent WHERE campaign_offer_product = A1)
# MEDIAN(offers.actual_offer_percent WHERE campaign_offer_product = C1)
# MEDIAN(offers.campaign_offer_percent WHERE campaign_take_up = Y)
# MEDIAN(offers.campaign_offer_percent WHERE campaign_offer_product = H2)
# MEDIAN(offers.campaign_offer_percent WHERE campaign_offer_product = H1)
# MEDIAN(offers.campaign_offer_percent WHERE campaign_offer_product = A2)
# MEDIAN(offers.campaign_offer_percent WHERE campaign_take_up = N)
# MEDIAN(offers.campaign_offer_percent WHERE campaign_offer_product = E1)
# MEDIAN(offers.campaign_offer_percent WHERE campaign_offer_product = A1)
# MEDIAN(offers.campaign_offer_percent WHERE campaign_offer_product = C1)
# TREND(offers.policy_annual_premium, campaign_offer_date WHERE campaign_take_up = Y)
# TREND(offers.policy_annual_premium, campaign_offer_date WHERE campaign_offer_product = H2)
# TREND(offers.policy_annual_premium, campaign_offer_date WHERE campaign_offer_product = H1)
# TREND(offers.policy_annual_premium, campaign_offer_date WHERE campaign_offer_product = A2)
# TREND(offers.policy_annual_premium, campaign_offer_date WHERE campaign_take_up = N)
# TREND(offers.policy_annual_premium, campaign_offer_date WHERE campaign_offer_product = E1)
# TREND(offers.policy_annual_premium, campaign_offer_date WHERE campaign_offer_product = A1)
# TREND(offers.policy_annual_premium, campaign_offer_date WHERE campaign_offer_product = C1)
# TREND(offers.current_holding, campaign_offer_date WHERE campaign_take_up = Y)
# TREND(offers.current_holding, campaign_offer_date WHERE campaign_offer_product = H2)
# TREND(offers.current_holding, campaign_offer_date WHERE campaign_offer_product = H1)
# TREND(offers.current_holding, campaign_offer_date WHERE campaign_offer_product = A2)
# TREND(offers.current_holding, campaign_offer_date WHERE campaign_take_up = N)
# TREND(offers.current_holding, campaign_offer_date WHERE campaign_offer_product = E1)
# TREND(offers.current_holding, campaign_offer_date WHERE campaign_offer_product = A1)
# TREND(offers.current_holding, campaign_offer_date WHERE campaign_offer_product = C1)
# TREND(offers.campaign_offer_percent, campaign_offer_date WHERE campaign_take_up = Y)
# TREND(offers.campaign_offer_percent, campaign_offer_date WHERE campaign_offer_product = H2)
# TREND(offers.campaign_offer_percent, campaign_offer_date WHERE campaign_offer_product = H1)
# TREND(offers.campaign_offer_percent, campaign_offer_date WHERE campaign_offer_product = A2)
# TREND(offers.campaign_offer_percent, campaign_offer_date WHERE campaign_take_up = N)
# TREND(offers.campaign_offer_percent, campaign_offer_date WHERE campaign_offer_product = E1)
# TREND(offers.campaign_offer_percent, campaign_offer_date WHERE campaign_offer_product = A1)
# TREND(offers.campaign_offer_percent, campaign_offer_date WHERE campaign_offer_product = C1)
# TREND(offers.campaign_premium, campaign_offer_date WHERE campaign_take_up = Y)
# TREND(offers.campaign_premium, campaign_offer_date WHERE campaign_offer_product = H2)
# TREND(offers.campaign_premium, campaign_offer_date WHERE campaign_offer_product = H1)
# TREND(offers.campaign_premium, campaign_offer_date WHERE campaign_offer_product = A2)
# TREND(offers.campaign_premium, campaign_offer_date WHERE campaign_take_up = N)
# TREND(offers.campaign_premium, campaign_offer_date WHERE campaign_offer_product = E1)
# TREND(offers.campaign_premium, campaign_offer_date WHERE campaign_offer_product = A1)
# TREND(offers.campaign_premium, campaign_offer_date WHERE campaign_offer_product = C1)
# TREND(offers.actual_offer_percent, campaign_offer_date WHERE campaign_take_up = Y)
# TREND(offers.actual_offer_percent, campaign_offer_date WHERE campaign_offer_product = H2)
# TREND(offers.actual_offer_percent, campaign_offer_date WHERE campaign_offer_product = H1)
# TREND(offers.actual_offer_percent, campaign_offer_date WHERE campaign_offer_product = A2)
# TREND(offers.actual_offer_percent, campaign_offer_date WHERE campaign_take_up = N)
# TREND(offers.actual_offer_percent, campaign_offer_date WHERE campaign_offer_product = E1)
# TREND(offers.actual_offer_percent, campaign_offer_date WHERE campaign_offer_product = A1)
# TREND(offers.actual_offer_percent, campaign_offer_date WHERE campaign_offer_product = C1)
# TREND(offers.offer_score, campaign_offer_date WHERE campaign_take_up = Y)
# TREND(offers.offer_score, campaign_offer_date WHERE campaign_offer_product = H2)
# TREND(offers.offer_score, campaign_offer_date WHERE campaign_offer_product = H1)
# TREND(offers.offer_score, campaign_offer_date WHERE campaign_offer_product = A2)
# TREND(offers.offer_score, campaign_offer_date WHERE campaign_take_up = N)
# TREND(offers.offer_score, campaign_offer_date WHERE campaign_offer_product = E1)
# TREND(offers.offer_score, campaign_offer_date WHERE campaign_offer_product = A1)
# TREND(offers.offer_score, campaign_offer_date WHERE campaign_offer_product = C1)
# AVG_TIME_BETWEEN(offers.campaign_offer_date WHERE campaign_take_up = Y)
# AVG_TIME_BETWEEN(offers.campaign_offer_date WHERE campaign_offer_product = H2)
# AVG_TIME_BETWEEN(offers.campaign_offer_date WHERE campaign_offer_product = H1)
# AVG_TIME_BETWEEN(offers.campaign_offer_date WHERE campaign_offer_product = A2)
# AVG_TIME_BETWEEN(offers.campaign_offer_date WHERE campaign_take_up = N)
# AVG_TIME_BETWEEN(offers.campaign_offer_date WHERE campaign_offer_product = E1)
# AVG_TIME_BETWEEN(offers.campaign_offer_date WHERE campaign_offer_product = A1)
# AVG_TIME_BETWEEN(offers.campaign_offer_date WHERE campaign_offer_product = C1)
# MIN(offers.offer_score WHERE campaign_take_up = Y)
# MIN(offers.offer_score WHERE campaign_offer_product = H2)
# MIN(offers.offer_score WHERE campaign_offer_product = H1)
# MIN(offers.offer_score WHERE campaign_offer_product = A2)
# MIN(offers.offer_score WHERE campaign_take_up = N)
# MIN(offers.offer_score WHERE campaign_offer_product = E1)
# MIN(offers.offer_score WHERE campaign_offer_product = A1)
# MIN(offers.offer_score WHERE campaign_offer_product = C1)
# MIN(offers.policy_annual_premium WHERE campaign_take_up = Y)
# MIN(offers.policy_annual_premium WHERE campaign_offer_product = H2)
# MIN(offers.policy_annual_premium WHERE campaign_offer_product = H1)
# MIN(offers.policy_annual_premium WHERE campaign_offer_product = A2)
# MIN(offers.policy_annual_premium WHERE campaign_take_up = N)
# MIN(offers.policy_annual_premium WHERE campaign_offer_product = E1)
# MIN(offers.policy_annual_premium WHERE campaign_offer_product = A1)
# MIN(offers.policy_annual_premium WHERE campaign_offer_product = C1)
# MIN(offers.current_holding WHERE campaign_take_up = Y)
# MIN(offers.current_holding WHERE campaign_offer_product = H2)
# MIN(offers.current_holding WHERE campaign_offer_product = H1)
# MIN(offers.current_holding WHERE campaign_offer_product = A2)
# MIN(offers.current_holding WHERE campaign_take_up = N)
# MIN(offers.current_holding WHERE campaign_offer_product = E1)
# MIN(offers.current_holding WHERE campaign_offer_product = A1)
# MIN(offers.current_holding WHERE campaign_offer_product = C1)
# MIN(offers.campaign_premium WHERE campaign_take_up = Y)
# MIN(offers.campaign_premium WHERE campaign_offer_product = H2)
# MIN(offers.campaign_premium WHERE campaign_offer_product = H1)
# MIN(offers.campaign_premium WHERE campaign_offer_product = A2)
# MIN(offers.campaign_premium WHERE campaign_take_up = N)
# MIN(offers.campaign_premium WHERE campaign_offer_product = E1)
# MIN(offers.campaign_premium WHERE campaign_offer_product = A1)
# MIN(offers.campaign_premium WHERE campaign_offer_product = C1)
# MIN(offers.actual_offer_percent WHERE campaign_take_up = Y)
# MIN(offers.actual_offer_percent WHERE campaign_offer_product = H2)
# MIN(offers.actual_offer_percent WHERE campaign_offer_product = H1)
# MIN(offers.actual_offer_percent WHERE campaign_offer_product = A2)
# MIN(offers.actual_offer_percent WHERE campaign_take_up = N)
# MIN(offers.actual_offer_percent WHERE campaign_offer_product = E1)
# MIN(offers.actual_offer_percent WHERE campaign_offer_product = A1)
# MIN(offers.actual_offer_percent WHERE campaign_offer_product = C1)
# MIN(offers.campaign_offer_percent WHERE campaign_take_up = Y)
# MIN(offers.campaign_offer_percent WHERE campaign_offer_product = H2)
# MIN(offers.campaign_offer_percent WHERE campaign_offer_product = H1)
# MIN(offers.campaign_offer_percent WHERE campaign_offer_product = A2)
# MIN(offers.campaign_offer_percent WHERE campaign_take_up = N)
# MIN(offers.campaign_offer_percent WHERE campaign_offer_product = E1)
# MIN(offers.campaign_offer_percent WHERE campaign_offer_product = A1)
# MIN(offers.campaign_offer_percent WHERE campaign_offer_product = C1)
# STD(offers.offer_score WHERE campaign_take_up = Y)
# STD(offers.offer_score WHERE campaign_offer_product = H2)
# STD(offers.offer_score WHERE campaign_offer_product = H1)
# STD(offers.offer_score WHERE campaign_offer_product = A2)
# STD(offers.offer_score WHERE campaign_take_up = N)
# STD(offers.offer_score WHERE campaign_offer_product = E1)
# STD(offers.offer_score WHERE campaign_offer_product = A1)
# STD(offers.offer_score WHERE campaign_offer_product = C1)
# STD(offers.policy_annual_premium WHERE campaign_take_up = Y)
# STD(offers.policy_annual_premium WHERE campaign_offer_product = H2)
# STD(offers.policy_annual_premium WHERE campaign_offer_product = H1)
# STD(offers.policy_annual_premium WHERE campaign_offer_product = A2)
# STD(offers.policy_annual_premium WHERE campaign_take_up = N)
# STD(offers.policy_annual_premium WHERE campaign_offer_product = E1)
# STD(offers.policy_annual_premium WHERE campaign_offer_product = A1)
# STD(offers.policy_annual_premium WHERE campaign_offer_product = C1)
# STD(offers.current_holding WHERE campaign_take_up = Y)
# STD(offers.current_holding WHERE campaign_offer_product = H2)
# STD(offers.current_holding WHERE campaign_offer_product = H1)
# STD(offers.current_holding WHERE campaign_offer_product = A2)
# STD(offers.current_holding WHERE campaign_take_up = N)
# STD(offers.current_holding WHERE campaign_offer_product = E1)
# STD(offers.current_holding WHERE campaign_offer_product = A1)
# STD(offers.current_holding WHERE campaign_offer_product = C1)
# STD(offers.campaign_premium WHERE campaign_take_up = Y)
# STD(offers.campaign_premium WHERE campaign_offer_product = H2)
# STD(offers.campaign_premium WHERE campaign_offer_product = H1)
# STD(offers.campaign_premium WHERE campaign_offer_product = A2)
# STD(offers.campaign_premium WHERE campaign_take_up = N)
# STD(offers.campaign_premium WHERE campaign_offer_product = E1)
# STD(offers.campaign_premium WHERE campaign_offer_product = A1)
# STD(offers.campaign_premium WHERE campaign_offer_product = C1)
# STD(offers.actual_offer_percent WHERE campaign_take_up = Y)
# STD(offers.actual_offer_percent WHERE campaign_offer_product = H2)
# STD(offers.actual_offer_percent WHERE campaign_offer_product = H1)
# STD(offers.actual_offer_percent WHERE campaign_offer_product = A2)
# STD(offers.actual_offer_percent WHERE campaign_take_up = N)
# STD(offers.actual_offer_percent WHERE campaign_offer_product = E1)
# STD(offers.actual_offer_percent WHERE campaign_offer_product = A1)
# STD(offers.actual_offer_percent WHERE campaign_offer_product = C1)
# STD(offers.campaign_offer_percent WHERE campaign_take_up = Y)
# STD(offers.campaign_offer_percent WHERE campaign_offer_product = H2)
# STD(offers.campaign_offer_percent WHERE campaign_offer_product = H1)
# STD(offers.campaign_offer_percent WHERE campaign_offer_product = A2)
# STD(offers.campaign_offer_percent WHERE campaign_take_up = N)
# STD(offers.campaign_offer_percent WHERE campaign_offer_product = E1)
# STD(offers.campaign_offer_percent WHERE campaign_offer_product = A1)
# STD(offers.campaign_offer_percent WHERE campaign_offer_product = C1)
# MEAN(offers.offer_score WHERE campaign_take_up = Y)
# MEAN(offers.offer_score WHERE campaign_offer_product = H2)
# MEAN(offers.offer_score WHERE campaign_offer_product = H1)
# MEAN(offers.offer_score WHERE campaign_offer_product = A2)
# MEAN(offers.offer_score WHERE campaign_take_up = N)
# MEAN(offers.offer_score WHERE campaign_offer_product = E1)
# MEAN(offers.offer_score WHERE campaign_offer_product = A1)
# MEAN(offers.offer_score WHERE campaign_offer_product = C1)
# MEAN(offers.policy_annual_premium WHERE campaign_take_up = Y)
# MEAN(offers.policy_annual_premium WHERE campaign_offer_product = H2)
# MEAN(offers.policy_annual_premium WHERE campaign_offer_product = H1)
# MEAN(offers.policy_annual_premium WHERE campaign_offer_product = A2)
# MEAN(offers.policy_annual_premium WHERE campaign_take_up = N)
# MEAN(offers.policy_annual_premium WHERE campaign_offer_product = E1)
# MEAN(offers.policy_annual_premium WHERE campaign_offer_product = A1)
# MEAN(offers.policy_annual_premium WHERE campaign_offer_product = C1)
# MEAN(offers.current_holding WHERE campaign_take_up = Y)
# MEAN(offers.current_holding WHERE campaign_offer_product = H2)
# MEAN(offers.current_holding WHERE campaign_offer_product = H1)
# MEAN(offers.current_holding WHERE campaign_offer_product = A2)
# MEAN(offers.current_holding WHERE campaign_take_up = N)
# MEAN(offers.current_holding WHERE campaign_offer_product = E1)
# MEAN(offers.current_holding WHERE campaign_offer_product = A1)
# MEAN(offers.current_holding WHERE campaign_offer_product = C1)
# MEAN(offers.campaign_premium WHERE campaign_take_up = Y)
# MEAN(offers.campaign_premium WHERE campaign_offer_product = H2)
# MEAN(offers.campaign_premium WHERE campaign_offer_product = H1)
# MEAN(offers.campaign_premium WHERE campaign_offer_product = A2)
# MEAN(offers.campaign_premium WHERE campaign_take_up = N)
# MEAN(offers.campaign_premium WHERE campaign_offer_product = E1)
# MEAN(offers.campaign_premium WHERE campaign_offer_product = A1)
# MEAN(offers.campaign_premium WHERE campaign_offer_product = C1)
# MEAN(offers.actual_offer_percent WHERE campaign_take_up = Y)
# MEAN(offers.actual_offer_percent WHERE campaign_offer_product = H2)
# MEAN(offers.actual_offer_percent WHERE campaign_offer_product = H1)
# MEAN(offers.actual_offer_percent WHERE campaign_offer_product = A2)
# MEAN(offers.actual_offer_percent WHERE campaign_take_up = N)
# MEAN(offers.actual_offer_percent WHERE campaign_offer_product = E1)
# MEAN(offers.actual_offer_percent WHERE campaign_offer_product = A1)
# MEAN(offers.actual_offer_percent WHERE campaign_offer_product = C1)
# MEAN(offers.campaign_offer_percent WHERE campaign_take_up = Y)
# MEAN(offers.campaign_offer_percent WHERE campaign_offer_product = H2)
# MEAN(offers.campaign_offer_percent WHERE campaign_offer_product = H1)
# MEAN(offers.campaign_offer_percent WHERE campaign_offer_product = A2)
# MEAN(offers.campaign_offer_percent WHERE campaign_take_up = N)
# MEAN(offers.campaign_offer_percent WHERE campaign_offer_product = E1)
# MEAN(offers.campaign_offer_percent WHERE campaign_offer_product = A1)
# MEAN(offers.campaign_offer_percent WHERE campaign_offer_product = C1)
# SUM(offers.offer_score WHERE campaign_take_up = Y)
# SUM(offers.offer_score WHERE campaign_offer_product = H2)
# SUM(offers.offer_score WHERE campaign_offer_product = H1)
# SUM(offers.offer_score WHERE campaign_offer_product = A2)
# SUM(offers.offer_score WHERE campaign_take_up = N)
# SUM(offers.offer_score WHERE campaign_offer_product = E1)
# SUM(offers.offer_score WHERE campaign_offer_product = A1)
# SUM(offers.offer_score WHERE campaign_offer_product = C1)
# SUM(offers.policy_annual_premium WHERE campaign_take_up = Y)
# SUM(offers.policy_annual_premium WHERE campaign_offer_product = H2)
# SUM(offers.policy_annual_premium WHERE campaign_offer_product = H1)
# SUM(offers.policy_annual_premium WHERE campaign_offer_product = A2)
# SUM(offers.policy_annual_premium WHERE campaign_take_up = N)
# SUM(offers.policy_annual_premium WHERE campaign_offer_product = E1)
# SUM(offers.policy_annual_premium WHERE campaign_offer_product = A1)
# SUM(offers.policy_annual_premium WHERE campaign_offer_product = C1)
# SUM(offers.current_holding WHERE campaign_take_up = Y)
# SUM(offers.current_holding WHERE campaign_offer_product = H2)
# SUM(offers.current_holding WHERE campaign_offer_product = H1)
# SUM(offers.current_holding WHERE campaign_offer_product = A2)
# SUM(offers.current_holding WHERE campaign_take_up = N)
# SUM(offers.current_holding WHERE campaign_offer_product = E1)
# SUM(offers.current_holding WHERE campaign_offer_product = A1)
# SUM(offers.current_holding WHERE campaign_offer_product = C1)
# SUM(offers.campaign_premium WHERE campaign_take_up = Y)
# SUM(offers.campaign_premium WHERE campaign_offer_product = H2)
# SUM(offers.campaign_premium WHERE campaign_offer_product = H1)
# SUM(offers.campaign_premium WHERE campaign_offer_product = A2)
# SUM(offers.campaign_premium WHERE campaign_take_up = N)
# SUM(offers.campaign_premium WHERE campaign_offer_product = E1)
# SUM(offers.campaign_premium WHERE campaign_offer_product = A1)
# SUM(offers.campaign_premium WHERE campaign_offer_product = C1)
# SUM(offers.actual_offer_percent WHERE campaign_take_up = Y)
# SUM(offers.actual_offer_percent WHERE campaign_offer_product = H2)
# SUM(offers.actual_offer_percent WHERE campaign_offer_product = H1)
# SUM(offers.actual_offer_percent WHERE campaign_offer_product = A2)
# SUM(offers.actual_offer_percent WHERE campaign_take_up = N)
# SUM(offers.actual_offer_percent WHERE campaign_offer_product = E1)
# SUM(offers.actual_offer_percent WHERE campaign_offer_product = A1)
# SUM(offers.actual_offer_percent WHERE campaign_offer_product = C1)
# SUM(offers.campaign_offer_percent WHERE campaign_take_up = Y)
# SUM(offers.campaign_offer_percent WHERE campaign_offer_product = H2)
# SUM(offers.campaign_offer_percent WHERE campaign_offer_product = H1)
# SUM(offers.campaign_offer_percent WHERE campaign_offer_product = A2)
# SUM(offers.campaign_offer_percent WHERE campaign_take_up = N)
# SUM(offers.campaign_offer_percent WHERE campaign_offer_product = E1)
# SUM(offers.campaign_offer_percent WHERE campaign_offer_product = A1)
# SUM(offers.campaign_offer_percent WHERE campaign_offer_product = C1)
# SKEW(offers.offer_score WHERE campaign_take_up = Y)
# SKEW(offers.offer_score WHERE campaign_offer_product = H2)
# SKEW(offers.offer_score WHERE campaign_offer_product = H1)
# SKEW(offers.offer_score WHERE campaign_offer_product = A2)
# SKEW(offers.offer_score WHERE campaign_take_up = N)
# SKEW(offers.offer_score WHERE campaign_offer_product = E1)
# SKEW(offers.offer_score WHERE campaign_offer_product = A1)
# SKEW(offers.offer_score WHERE campaign_offer_product = C1)
# SKEW(offers.policy_annual_premium WHERE campaign_take_up = Y)
# SKEW(offers.policy_annual_premium WHERE campaign_offer_product = H2)
# SKEW(offers.policy_annual_premium WHERE campaign_offer_product = H1)
# SKEW(offers.policy_annual_premium WHERE campaign_offer_product = A2)
# SKEW(offers.policy_annual_premium WHERE campaign_take_up = N)
# SKEW(offers.policy_annual_premium WHERE campaign_offer_product = E1)
# SKEW(offers.policy_annual_premium WHERE campaign_offer_product = A1)
# SKEW(offers.policy_annual_premium WHERE campaign_offer_product = C1)
# SKEW(offers.current_holding WHERE campaign_take_up = Y)
# SKEW(offers.current_holding WHERE campaign_offer_product = H2)
# SKEW(offers.current_holding WHERE campaign_offer_product = H1)
# SKEW(offers.current_holding WHERE campaign_offer_product = A2)
# SKEW(offers.current_holding WHERE campaign_take_up = N)
# SKEW(offers.current_holding WHERE campaign_offer_product = E1)
# SKEW(offers.current_holding WHERE campaign_offer_product = A1)
# SKEW(offers.current_holding WHERE campaign_offer_product = C1)
# SKEW(offers.campaign_premium WHERE campaign_take_up = Y)
# SKEW(offers.campaign_premium WHERE campaign_offer_product = H2)
# SKEW(offers.campaign_premium WHERE campaign_offer_product = H1)
# SKEW(offers.campaign_premium WHERE campaign_offer_product = A2)
# SKEW(offers.campaign_premium WHERE campaign_take_up = N)
# SKEW(offers.campaign_premium WHERE campaign_offer_product = E1)
# SKEW(offers.campaign_premium WHERE campaign_offer_product = A1)
# SKEW(offers.campaign_premium WHERE campaign_offer_product = C1)
# SKEW(offers.actual_offer_percent WHERE campaign_take_up = Y)
# SKEW(offers.actual_offer_percent WHERE campaign_offer_product = H2)
# SKEW(offers.actual_offer_percent WHERE campaign_offer_product = H1)
# SKEW(offers.actual_offer_percent WHERE campaign_offer_product = A2)
# SKEW(offers.actual_offer_percent WHERE campaign_take_up = N)
# SKEW(offers.actual_offer_percent WHERE campaign_offer_product = E1)
# SKEW(offers.actual_offer_percent WHERE campaign_offer_product = A1)
# SKEW(offers.actual_offer_percent WHERE campaign_offer_product = C1)
# SKEW(offers.campaign_offer_percent WHERE campaign_take_up = Y)
# SKEW(offers.campaign_offer_percent WHERE campaign_offer_product = H2)
# SKEW(offers.campaign_offer_percent WHERE campaign_offer_product = H1)
# SKEW(offers.campaign_offer_percent WHERE campaign_offer_product = A2)
# SKEW(offers.campaign_offer_percent WHERE campaign_take_up = N)
# SKEW(offers.campaign_offer_percent WHERE campaign_offer_product = E1)
# SKEW(offers.campaign_offer_percent WHERE campaign_offer_product = A1)
# SKEW(offers.campaign_offer_percent WHERE campaign_offer_product = C1)
# MODE(offers.campaign_offer_product WHERE campaign_take_up = Y)
# MODE(offers.campaign_offer_product WHERE campaign_take_up = N)
# MODE(offers.MONTH(campaign_offer_date))
# MODE(offers.MONTH(campaign_offer_date) WHERE campaign_take_up = Y)
# MODE(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = H2)
# MODE(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = H1)
# MODE(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = A2)
# MODE(offers.MONTH(campaign_offer_date) WHERE campaign_take_up = N)
# MODE(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = E1)
# MODE(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = A1)
# MODE(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = C1)
# MODE(offers.YEAR(campaign_offer_date))
# MODE(offers.YEAR(campaign_offer_date) WHERE campaign_take_up = Y)
# MODE(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = H2)
# MODE(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = H1)
# MODE(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = A2)
# MODE(offers.YEAR(campaign_offer_date) WHERE campaign_take_up = N)
# MODE(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = E1)
# MODE(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = A1)
# MODE(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = C1)
# MODE(offers.campaign_take_up WHERE campaign_offer_product = H2)
# MODE(offers.campaign_take_up WHERE campaign_offer_product = H1)
# MODE(offers.campaign_take_up WHERE campaign_offer_product = A2)
# MODE(offers.campaign_take_up WHERE campaign_offer_product = E1)
# MODE(offers.campaign_take_up WHERE campaign_offer_product = A1)
# MODE(offers.campaign_take_up WHERE campaign_offer_product = C1)
# MODE(offers.DAY(campaign_offer_date))
# MODE(offers.DAY(campaign_offer_date) WHERE campaign_take_up = Y)
# MODE(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = H2)
# MODE(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = H1)
# MODE(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = A2)
# MODE(offers.DAY(campaign_offer_date) WHERE campaign_take_up = N)
# MODE(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = E1)
# MODE(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = A1)
# MODE(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = C1)
# MODE(offers.WEEKDAY(campaign_offer_date))
# MODE(offers.WEEKDAY(campaign_offer_date) WHERE campaign_take_up = Y)
# MODE(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = H2)
# MODE(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = H1)
# MODE(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = A2)
# MODE(offers.WEEKDAY(campaign_offer_date) WHERE campaign_take_up = N)
# MODE(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = E1)
# MODE(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = A1)
# MODE(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = C1)
# LAST(offers.offer_score WHERE campaign_take_up = Y)
# LAST(offers.offer_score WHERE campaign_offer_product = H2)
# LAST(offers.offer_score WHERE campaign_offer_product = H1)
# LAST(offers.offer_score WHERE campaign_offer_product = A2)
# LAST(offers.offer_score WHERE campaign_take_up = N)
# LAST(offers.offer_score WHERE campaign_offer_product = E1)
# LAST(offers.offer_score WHERE campaign_offer_product = A1)
# LAST(offers.offer_score WHERE campaign_offer_product = C1)
# LAST(offers.policy_annual_premium WHERE campaign_take_up = Y)
# LAST(offers.policy_annual_premium WHERE campaign_offer_product = H2)
# LAST(offers.policy_annual_premium WHERE campaign_offer_product = H1)
# LAST(offers.policy_annual_premium WHERE campaign_offer_product = A2)
# LAST(offers.policy_annual_premium WHERE campaign_take_up = N)
# LAST(offers.policy_annual_premium WHERE campaign_offer_product = E1)
# LAST(offers.policy_annual_premium WHERE campaign_offer_product = A1)
# LAST(offers.policy_annual_premium WHERE campaign_offer_product = C1)
# LAST(offers.current_holding WHERE campaign_take_up = Y)
# LAST(offers.current_holding WHERE campaign_offer_product = H2)
# LAST(offers.current_holding WHERE campaign_offer_product = H1)
# LAST(offers.current_holding WHERE campaign_offer_product = A2)
# LAST(offers.current_holding WHERE campaign_take_up = N)
# LAST(offers.current_holding WHERE campaign_offer_product = E1)
# LAST(offers.current_holding WHERE campaign_offer_product = A1)
# LAST(offers.current_holding WHERE campaign_offer_product = C1)
# LAST(offers.campaign_offer_product WHERE campaign_take_up = Y)
# LAST(offers.campaign_offer_product WHERE campaign_take_up = N)
# LAST(offers.campaign_premium WHERE campaign_take_up = Y)
# LAST(offers.campaign_premium WHERE campaign_offer_product = H2)
# LAST(offers.campaign_premium WHERE campaign_offer_product = H1)
# LAST(offers.campaign_premium WHERE campaign_offer_product = A2)
# LAST(offers.campaign_premium WHERE campaign_take_up = N)
# LAST(offers.campaign_premium WHERE campaign_offer_product = E1)
# LAST(offers.campaign_premium WHERE campaign_offer_product = A1)
# LAST(offers.campaign_premium WHERE campaign_offer_product = C1)
# LAST(offers.actual_offer_percent WHERE campaign_take_up = Y)
# LAST(offers.actual_offer_percent WHERE campaign_offer_product = H2)
# LAST(offers.actual_offer_percent WHERE campaign_offer_product = H1)
# LAST(offers.actual_offer_percent WHERE campaign_offer_product = A2)
# LAST(offers.actual_offer_percent WHERE campaign_take_up = N)
# LAST(offers.actual_offer_percent WHERE campaign_offer_product = E1)
# LAST(offers.actual_offer_percent WHERE campaign_offer_product = A1)
# LAST(offers.actual_offer_percent WHERE campaign_offer_product = C1)
# LAST(offers.MONTH(campaign_offer_date))
# LAST(offers.MONTH(campaign_offer_date) WHERE campaign_take_up = Y)
# LAST(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = H2)
# LAST(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = H1)
# LAST(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = A2)
# LAST(offers.MONTH(campaign_offer_date) WHERE campaign_take_up = N)
# LAST(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = E1)
# LAST(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = A1)
# LAST(offers.MONTH(campaign_offer_date) WHERE campaign_offer_product = C1)
# LAST(offers.YEAR(campaign_offer_date))
# LAST(offers.YEAR(campaign_offer_date) WHERE campaign_take_up = Y)
# LAST(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = H2)
# LAST(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = H1)
# LAST(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = A2)
# LAST(offers.YEAR(campaign_offer_date) WHERE campaign_take_up = N)
# LAST(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = E1)
# LAST(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = A1)
# LAST(offers.YEAR(campaign_offer_date) WHERE campaign_offer_product = C1)
# LAST(offers.campaign_offer_percent WHERE campaign_take_up = Y)
# LAST(offers.campaign_offer_percent WHERE campaign_offer_product = H2)
# LAST(offers.campaign_offer_percent WHERE campaign_offer_product = H1)
# LAST(offers.campaign_offer_percent WHERE campaign_offer_product = A2)
# LAST(offers.campaign_offer_percent WHERE campaign_take_up = N)
# LAST(offers.campaign_offer_percent WHERE campaign_offer_product = E1)
# LAST(offers.campaign_offer_percent WHERE campaign_offer_product = A1)
# LAST(offers.campaign_offer_percent WHERE campaign_offer_product = C1)
# LAST(offers.campaign_take_up WHERE campaign_offer_product = H2)
# LAST(offers.campaign_take_up WHERE campaign_offer_product = H1)
# LAST(offers.campaign_take_up WHERE campaign_offer_product = A2)
# LAST(offers.campaign_take_up WHERE campaign_offer_product = E1)
# LAST(offers.campaign_take_up WHERE campaign_offer_product = A1)
# LAST(offers.campaign_take_up WHERE campaign_offer_product = C1)
# LAST(offers.DAY(campaign_offer_date))
# LAST(offers.DAY(campaign_offer_date) WHERE campaign_take_up = Y)
# LAST(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = H2)
# LAST(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = H1)
# LAST(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = A2)
# LAST(offers.DAY(campaign_offer_date) WHERE campaign_take_up = N)
# LAST(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = E1)
# LAST(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = A1)
# LAST(offers.DAY(campaign_offer_date) WHERE campaign_offer_product = C1)
# LAST(offers.WEEKDAY(campaign_offer_date))
# LAST(offers.WEEKDAY(campaign_offer_date) WHERE campaign_take_up = Y)
# LAST(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = H2)
# LAST(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = H1)
# LAST(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = A2)
# LAST(offers.WEEKDAY(campaign_offer_date) WHERE campaign_take_up = N)
# LAST(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = E1)
# LAST(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = A1)
# LAST(offers.WEEKDAY(campaign_offer_date) WHERE campaign_offer_product = C1)
# TIME_SINCE_FIRST(offers.campaign_offer_date WHERE campaign_take_up = Y)
# TIME_SINCE_FIRST(offers.campaign_offer_date WHERE campaign_offer_product = H2)
# TIME_SINCE_FIRST(offers.campaign_offer_date WHERE campaign_offer_product = H1)
# TIME_SINCE_FIRST(offers.campaign_offer_date WHERE campaign_offer_product = A2)
# TIME_SINCE_FIRST(offers.campaign_offer_date WHERE campaign_take_up = N)
# TIME_SINCE_FIRST(offers.campaign_offer_date WHERE campaign_offer_product = E1)
# TIME_SINCE_FIRST(offers.campaign_offer_date WHERE campaign_offer_product = A1)
# TIME_SINCE_FIRST(offers.campaign_offer_date WHERE campaign_offer_product = C1)
# DAY(LAST(offers.campaign_offer_date))
# YEAR(LAST(offers.campaign_offer_date))
# MONTH(LAST(offers.campaign_offer_date))
# WEEKDAY(LAST(offers.campaign_offer_date))

# %%
agg_ft = ft.primitives.list_primitives()
agg_ft[agg_ft['type'] == 'aggregation']
# Out:
#                 name         type  \
# 0                std  aggregation
# 1         num_unique  aggregation
# 2   time_since_first  aggregation
# 3                sum  aggregation
# 4               skew  aggregation
# 5                max  aggregation
# 6               mean  aggregation
# 7   avg_time_between  aggregation
# 8    time_since_last  aggregation
# 9             median  aggregation
# 10               min  aggregation
# 11               all  aggregation
# 12     n_most_common  aggregation
# 13              mode  aggregation
# 14               any  aggregation
# 15      percent_true  aggregation
# 16             count  aggregation
# 17              last  aggregation
# 18          num_true  aggregation
# 19             trend  aggregation
#
#                                           description
# 0   Computes the dispersion relative to the mean v...
# 1   Determines the number of distinct values, igno...
# 2   Calculates the time elapsed since the first da...
# 3      Calculates the total addition, ignoring `NaN`.
# 4   Computes the extent to which a distribution di...
# 5   Calculates the highest value, ignoring `NaN` v...
# 6          Computes the average for a list of values.
# 7   Computes the average number of seconds between...
# 8   Calculates the time elapsed since the last dat...
# 9   Determines the middlemost number in a list of ...
# 10  Calculates the smallest value, ignoring `NaN` ...
# 11     Calculates if all values are 'True' in a list.
# 12           Determines the `n` most common elements.
# 13       Determines the most commonly repeated value.
# 14       Determines if any value is 'True' in a list.
# 15           Determines the percent of `True` values.
# 16  Determines the total number of values, excludi...
# 17               Determines the last value in a list.
# 18                Counts the number of `True` values.
# 19      Calculates the trend of a variable over time.

# %%
agg_ft['type'].value_counts()
# Out:
#                        name         type  \
# 0                       std  aggregation
# 1                num_unique  aggregation
# 2          time_since_first  aggregation
# 3                       sum  aggregation
# 4                      skew  aggregation
# 5                       max  aggregation
# 6                      mean  aggregation
# 7          avg_time_between  aggregation
# 8           time_since_last  aggregation
# 9                    median  aggregation
# 10                      min  aggregation
# 11                      all  aggregation
# 12            n_most_common  aggregation
# 13                     mode  aggregation
# 14                      any  aggregation
# 15             percent_true  aggregation
# 16                    count  aggregation
# 17                     last  aggregation
# 18                 num_true  aggregation
# 19                    trend  aggregation
# 20                  cum_sum    transform
# 21        divide_by_feature    transform
# 22                not_equal    transform
# 23                 latitude    transform
# 24                     year    transform
# 25           divide_numeric    transform
# 26                    equal    transform
# 27                      not    transform
# 28                     week    transform
# 29         multiply_numeric    transform
# 30       less_than_equal_to    transform
# 31                     diff    transform
# 32                   second    transform
# 33             greater_than    transform
# 34    modulo_numeric_scalar    transform
# 35    greater_than_equal_to    transform
# 36                       or    transform
# 37  subtract_numeric_scalar    transform
# 38               time_since    transform
# 39                      day    transform
# 40                less_than    transform
# 41                  cum_min    transform
# 42        modulo_by_feature    transform
# 43       add_numeric_scalar    transform
# 44           num_characters    transform
# 45      time_since_previous    transform
# 46                cum_count    transform
# 47                  is_null    transform
# 48           modulo_numeric    transform
# 49                longitude    transform
#
#                                           description
# 0   Computes the dispersion relative to the mean v...
# 1   Determines the number of distinct values, igno...
# 2   Calculates the time elapsed since the first da...
# 3      Calculates the total addition, ignoring `NaN`.
# 4   Computes the extent to which a distribution di...
# 5   Calculates the highest value, ignoring `NaN` v...
# 6          Computes the average for a list of values.
# 7   Computes the average number of seconds between...
# 8   Calculates the time elapsed since the last dat...
# 9   Determines the middlemost number in a list of ...
# 10  Calculates the smallest value, ignoring `NaN` ...
# 11     Calculates if all values are 'True' in a list.
# 12           Determines the `n` most common elements.
# 13       Determines the most commonly repeated value.
# 14       Determines if any value is 'True' in a list.
# 15           Determines the percent of `True` values.
# 16  Determines the total number of values, excludi...
# 17               Determines the last value in a list.
# 18                Counts the number of `True` values.
# 19      Calculates the trend of a variable over time.
# 20                     Calculates the cumulative sum.
# 21         Divide a scalar by each value in the list.
# 22  Determines if values in one list are not equal...
# 23  Returns the first tuple value in a list of Lat...
# 24           Determines the year value of a datetime.
# 25                Element-wise division of two lists.
# 26  Determines if values in one list are equal to ...
# 27                           Negates a boolean value.
# 28   Determines the week of the year from a datetime.
# 29          Element-wise multiplication of two lists.
# 30  Determines if values in one list are less than...
# 31  Compute the difference between the value in a ...
# 32        Determines the seconds value of a datetime.
# 33  Determines if values in one list are greater t...
# 34  Return the modulo of each element in the list ...
# 35  Determines if values in one list are greater t...
# 36              Element-wise logical OR of two lists.
# 37   Subtract a scalar from each element in the list.
# 38  Calculates time from a value to a specified cu...
# 39   Determines the day of the month from a datetime.
# 40  Determines if values in one list are less than...
# 41                 Calculates the cumulative minimum.
# 42  Return the modulo of a scalar by each element ...
# 43            Add a scalar to each value in the list.
# 44   Calculates the number of characters in a string.
# 45  Compute the time since the previous entry in a...
# 46                   Calculates the cumulative count.
# 47                     Determines if a value is null.
# 48                  Element-wise modulo of two lists.
# 49  Returns the second tuple value in a list of La...
